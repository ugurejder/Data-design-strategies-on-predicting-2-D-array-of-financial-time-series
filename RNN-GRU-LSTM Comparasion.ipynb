# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression
from bokeh.plotting import figure, show
import tensorflow as tf
import time 
from datetime import timedelta
import os
os.chdir(path=r'C:\Users\LenovoE73\Desktop\data')
#import FinanceLab as finlab
import scipy 
import statistics as stat 
import stockstats
import researchpy as rp
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
from pandas.api.types import CategoricalDtype
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import f1_score
import statsmodels.formula.api as smf
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
#from catboost import CatBoostClassifier
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from warnings import filterwarnings
filterwarnings('ignore')
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # confusion_matrix_returns function

# %%
def confusion_matrix_returns(y_test_f,predicted_class1_f):
    cm_tam_yeni = confusion_matrix(list(y_test_f), list(predicted_class1_f)).ravel()
    cm_tam_yeni_len =len(cm_tam_yeni)
    root= int(pow(cm_tam_yeni_len, 0.5))
    confusion_matrix_m = cm_tam_yeni.reshape(root,root)
    FP = confusion_matrix_m.sum(axis=0) - np.diag(confusion_matrix_m)  
    FN = confusion_matrix_m.sum(axis=1) - np.diag(confusion_matrix_m)
    TP = np.diag(confusion_matrix_m)
    TN = confusion_matrix_m.sum() - (FP + FN + TP)

    FP = FP.astype(float)
    FN = FN.astype(float)
    TP = TP.astype(float)
    TN = TN.astype(float)


    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)


    f1_score =(2*(PPV * TPR))/(PPV + TPR)


    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)

    accuracy = ACC.mean()
    Precision = PPV.mean()
    Sensitivity = TPR.mean()
    Specificity = TNR.mean()
    f1_score =(2*(Precision * Sensitivity))/(Precision + Sensitivity)
    
    print("Accuracy: " , accuracy)
    print("Precision: " , PPV.mean())
    print("Sensitivity: " , TPR.mean())
    print("Specificity: " , TNR.mean())
    print("F1_Score: " , f1_score.mean())
    return accuracy,Precision, Sensitivity, Specificity, f1_score

# %% [markdown]
# # GRU Results

# %%
GRU_EXCEL = 'GRU_Full_Class'
LSTM_EXCEL= 'LSTM_Full_Class'
RNN_EXCEL= 'RNN_Full_Class'


post_fix =".xlsx"
#change directory
os.chdir(path=r'C:\\Users\\LenovoE73\\Desktop\\data\\tez_datalar\\Full')

#################### GRU #################### 

xl = pd.ExcelFile(GRU_EXCEL+post_fix)
# Print the sheet names

# Load a sheet into a DataFrame by name: GRU
df_GRU = xl.parse(GRU_EXCEL)

#################### LSTM #################### 

xl = pd.ExcelFile(LSTM_EXCEL+post_fix)
# Print the sheet names

# Load a sheet into a DataFrame by name: GRU
df_LSTM = xl.parse(LSTM_EXCEL)

#################### RNN #################### 


xl = pd.ExcelFile(RNN_EXCEL+post_fix)
# Print the sheet names

# Load a sheet into a DataFrame by name: GRU
df_RNN = xl.parse(RNN_EXCEL)

# %%
df_GRU["test_label"]
# Out:
#       Unnamed: 0                  stock_code  test_label  predict_label
# 0              0          ADEL10_Kazanc.xlsx           1              2
# 1              1          ADEL11_Kazanc.xlsx           1              2
# 2              2          ADEL12_Kazanc.xlsx           1              2
# 3              3          ADEL13_Kazanc.xlsx           1              2
# 4              4          ADEL14_Kazanc.xlsx           1              2
# 5              5          ADEL15_Kazanc.xlsx           1              2
# 6              6          ADEL16_Kazanc.xlsx           1              2
# 7              7            ADEL1_Tuzak.xlsx           2              2
# 8              8           ADEL2_Kazanc.xlsx           1              2
# 9              9            ADEL2_Tuzak.xlsx           2              2
# 10            10           ADEL3_Kazanc.xlsx           1              2
# 11            11            ADEL3_Tuzak.xlsx           2              2
# ...

# %%
#################### GRU #################### 

y_test_GRU = list(df_GRU["test_label"])
predicted_values_GRU = list(df_GRU["predict_label"])

#################### LSTM #################### 

y_test_LSTM = list(df_LSTM["test_label"])
predicted_values_LSTM = list(df_LSTM["predict_label"])


#################### RNN #################### 

y_test_RNN = list(df_RNN["test_label"])
predicted_values_RNN = list(df_RNN["predict_label"])

# %%
 print(classification_report(list(y_test_GRU), list(predicted_values_GRU), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            1     0.8421    0.7504    0.7936      1947
#            2     0.6653    0.7790    0.7177      1240
#            3     0.6527    0.1405    0.2312      1993
#            4     0.3814    0.8763    0.5315      1205
#
#     accuracy                         0.5894      6385
#    macro avg     0.6354    0.6366    0.5685      6385
# weighted avg     0.6617    0.5894    0.5538      6385

# %%
 print(classification_report(list(y_test_LSTM), list(predicted_values_LSTM), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            1     0.7625    0.3215    0.4523      1947
#            2     0.4417    0.8427    0.5796      1240
#            3     0.7680    0.2092    0.3289      1993
#            4     0.4064    0.8954    0.5591      1205
#
#     accuracy                         0.4960      6385
#    macro avg     0.5946    0.5672    0.4800      6385
# weighted avg     0.6347    0.4960    0.4586      6385

# %%
 print(classification_report(list(y_test_RNN), list(predicted_values_RNN), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            1     0.7419    0.3017    0.4290      1962
#            2     0.4315    0.8347    0.5689      1246
#            3     0.7850    0.2253    0.3501      1993
#            4     0.4120    0.8979    0.5649      1205
#
#     accuracy                         0.4938      6406
#    macro avg     0.5926    0.5649    0.4782      6406
# weighted avg     0.6329    0.4938    0.4572      6406

# %%
print("GRU")
accuracy,Precision, Sensitivity, Specificity, f1_score = confusion_matrix_returns(list(y_test_GRU), list(predicted_values_GRU))
# Out:
# GRU
# Accuracy:  0.7946750195771338
# Precision:  0.6353524876480925
# Sensitivity:  0.636564433704567
# Specificity:  0.8697948842092181
# F1_Score:  0.6359578832749212

# %%
print("LSTM")
accuracy,Precision, Sensitivity, Specificity, f1_score = confusion_matrix_returns(list(y_test_LSTM), list(predicted_values_LSTM))
# Out:
# LSTM
# Accuracy:  0.7480031323414252
# Precision:  0.5946293249642923
# Sensitivity:  0.5672325552122479
# Specificity:  0.8415928824520185
# F1_Score:  0.5806079313874716

# %%
print("RNN")
accuracy,Precision, Sensitivity, Specificity, f1_score = confusion_matrix_returns(list(y_test_RNN), list(predicted_values_RNN))
# Out:
# RNN
# Accuracy:  0.7468779269434904
# Precision:  0.5925971130773673
# Sensitivity:  0.5649044234010496
# Specificity:  0.8408508263680372
# F1_Score:  0.5784195008337922

# %%
accuracy_score(y_test_GRU,predicted_values_GRU)
# Out:
# 0.5893500391542679

# %%
acc_list = [59.19,
54.36,
55.61,
54.21,
54.83,
58.49,
57.48,
52.65,
52.96,
57.01,
56.62,
52.65,
57.32,
53.58,
57.24,
56.93,
55.30,
57.01,
53.58,
54.05,
52.49,
56.07,
57.40,
57.94,
54.91,
53.58,
57.01,
52.02,
56.54,
55.30,
54.60,
53.12]

# %%
X_new = np.array(acc_list)

# %%
plt.bar(Acc_models,
        Acc_score
        )

plt.title("Machine Learning Inluenza Class Results")
plt.show()

# %%
ax = sns.barplot(x="Methods", y="result", data=data_Inluenza, palette="summer",ci=195, n_boot=2000, )
ax.set(xlabel="Machine Learning Predict Inluenza Class Models", ylabel = "Accuracy_Score(%)", )

# %%
years = []
for i in range(1,33):
    years.append(i)

# %%
# Define plot space
fig, ax = plt.subplots(figsize=(10, 6))

# Define x and y axes
ax.scatter(years, 
        X_new)

plt.show()

# %%
# Define plot space
fig, ax = plt.subplots(figsize=(6, 4))

# Define x and y axes
ax.bar(Acc_models, 
        Acc_score,
        color=['Green','Blue','Orange','Red','Brown']
   )

# Set plot title and axes labels
'''ax.set(title = "Bencmarking Models",
       xlabel = "Models Name",
       ylabel = "Accuracy Score(%)",
       fontsize = 8
      )
'''
ax.set_xlabel('X axis', fontsize = 12)
ax.set_ylabel('Y axis', fontsize = 12)
plt.show()

# %%
os.chdir('C:\\Users\\LenovoE73\\Desktop\\tez_makale\\tez_calismalari\\kitap calismasi')

# %%
xl = pd.ExcelFile('cnn_results.xlsx')
# Print the sheet names

# Load a sheet into a DataFrame by name: GRU
df_cnn_results = xl.parse('cnn_results')

# %%
df_cnn_results.sort_values('F1-Score')
# Out:
#     No  Cnn Model  Time Frame size  Exe.Time    Acc  Precision  F1-Score
# 7    8          2              125       181  52.65      54.28     45.37
# 31  32          8              125       172  53.12      52.42     47.86
# 8    9          3               50        27  52.96      51.93     47.94
# 25  26          7               75        98  53.58      50.99     48.04
# 11  12          3              125        65  52.65      50.30     48.13
# 27  28          7              125       160  52.02      49.96     48.60
# 20  21          6               50        27  52.49      51.95     49.17
# 13  14          4               75        39  53.58      52.98     49.46
# 18  19          5              100        39  53.58      52.10     49.89
# 2    3          1              100       147  55.61      53.13     50.45
# 1    2          1               75       109  54.36      53.51     51.03
# 3    4          1              125       192  54.21      52.10     51.54
# ...

# %%
Acc_models= ['#Modified_CNN_No1','GRU','#Modified_CNN_No28','LSTM','RNN']

# %%
Acc_score=[59.19, 58.94 , 52.02,49.60 ,49.38 ]

# %%
Precision_models= ['#Modified_CNN_No6','GRU','#Modified_CNN_No28','LSTM','RNN']

# %%
Precision_score=[58.49, 58.94 , 52.02, 59.46 ,59.26 ]

# %%
F1_Score_models= ['#Modified_CNN_No6','GRU','#Modified_CNN_No8','LSTM','RNN']

# %%
F1_Score_score = [58.32, 55.38 , 45.37,  45.86 ,45.72 ]

# %% [markdown]
# # get results

# %%
os.chdir('C:\\Users\\LenovoE73\\Desktop\\tez_makale\\tez_calismalari\\kitap calismasi')
xl = pd.ExcelFile('cnn_results.xlsx')
# Print the sheet names

# Load a sheet into a DataFrame by name: GRU
df_all = xl.parse('comparasion')
df_all
# Out:
#     No              Models  Score(%)       Type
# 0    1   #Modified_CNN_No1     59.19        Acc
# 1    2                 GRU     58.94        Acc
# 2    3  #Modified_CNN_No28     52.02        Acc
# 3    4                LSTM     49.60        Acc
# 4    5                 RNN     49.38        Acc
# 5    6   #Modified_CNN_No6     58.32  Precision
# 6    7                 GRU     63.54  Precision
# 7    8  #Modified_CNN_No28     49.96  Precision
# 8    9                LSTM     59.46  Precision
# 9   10                 RNN     59.26  Precision
# 10  11   #Modified_CNN_No6     57.72   F1_score
# 11  12                 GRU     55.38   F1_score
# 12  13   #Modified_CNN_No8     45.37   F1_score
# 13  14                LSTM     45.86   F1_score
# 14  15                 RNN     45.72   F1_score

# %%
#sns.relplot(x='model', y='Score', data=df_all,hue="Type")


plt.figure(figsize=(10, 8)) 
scatter_preco_area = sns.relplot(data = df_all,
                                 x = "Models", y = "Score(%)", hue = "Type", height = 12, aspect = 1.25)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 4))

tips['bill level'] = pd.cut(tips["total_bill"], [0, 30, 1000], labels=["≤ 30", "> 30"])
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="bill level", palette=['turquoise', 'crimson'], ax=ax1)
ax1.set_title('2 levels, 2 colors')

tips['bill level'] = pd.cut(tips["total_bill"], bins=7, labels=[f'level {i}' for i in range(1, 8)])
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="bill level", palette='Set2', ax=ax2)
ax2.set_title('7 levels, 7 colors')

plt.tight_layout()
plt.show()

# %%
df_acc = pd.DataFrame({'Acc_models':['#Modified_CNN_No1','GRU','#Modified_CNN_No28','LSTM','RNN'],
                   'Acc_score':[59.19, 63.54, 49.96, 45.86 ,45.72 ]})

# %%
df_Precision= pd.DataFrame({'Precision_models':['#Modified_CNN_No6','GRU','#Modified_CNN_No28','LSTM','RNN'],
                   'Precision_score':[58.49, 58.94 , 52.02, 59.46 ,59.26 ]})

# %%
df_F1_Score_model= pd.DataFrame({'F1_Score_models':['#Modified_CNN_No6','GRU','#Modified_CNN_No8','LSTM','RNN'],
                   'F1_Score_score':[58.32, 55.38 , 45.37,  45.86 ,45.72 ]})

# %%
df_F1_Score_model
# Out:
#      F1_Score_models  F1_Score_score
# 0  #Modified_CNN_No6           58.32
# 1                GRU           55.38
# 2  #Modified_CNN_No8           45.37
# 3               LSTM           45.86
# 4                RNN           45.72

# %%
# Out:
#   Acc_models  Acc_score F1_Score_models  F1_Score_score Precision_models  \
# 0        NaN        NaN             NaN             NaN              NaN
# 1        NaN        NaN             NaN             NaN              NaN
# 2        NaN        NaN             NaN             NaN              NaN
# 3        NaN        NaN             NaN             NaN              NaN
# 4        NaN        NaN             NaN             NaN              NaN
#
#    Precision_score
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
import seaborn as sns



# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df_all, kind="bar",
    x="No", y="Score", hue="Type",
     alpha=.6, height=12
)
g.despine(left=True)
g.set_axis_labels("", "Accuracy(%)")

g.set_ylabels( "Accuracy(%)")

# %%
import missingno
missingno.bar(df, figsize=(10,5), fontsize=12);
