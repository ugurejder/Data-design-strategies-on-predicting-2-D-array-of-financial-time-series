# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from warnings import filterwarnings
filterwarnings('ignore')
import statsmodels.formula.api as smf
from bokeh.plotting import figure, show
import os
import tensorflow as tf
import numpy as np
import time 
from datetime import timedelta
import os
import stockstats
os.chdir(path=r'C:\\Users\\LenovoE73\\Desktop\\data\\tez_datalar');
import FinanceLab as finlab
import scipy 
import statistics as stat 
import stockstats
from functools import wraps
from pandas import DataFrame, Series
from pathlib import Path

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression
from bokeh.plotting import figure, show
import tensorflow as tf
import time 
from datetime import timedelta
import os
os.chdir(path=r'C:\Users\LenovoE73\Desktop\data')
#import FinanceLab as finlab
import scipy 
import statistics as stat 
import stockstats
import researchpy as rp
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
from pandas.api.types import CategoricalDtype
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import f1_score
import statsmodels.formula.api as smf
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
#from catboost import CatBoostClassifier
import missingno as msno
import seaborn as sns 
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
 #Excellerin alınacağı Path e geldik
os.chdir(path=r'C:\\Users\\LenovoE73\\Desktop\\tez_makale\\tez_calismalari\\2.tez_makale')

# %%
excel_ismi = 'summary.xlsx'

# %%
xl = pd.ExcelFile(excel_ismi)

# %%
hisse = xl.parse(excel_ismi)

# %%
hisse.sort_values("No")
# Out:
#     No                         CNN Type  Accuracy  precision  recall  \
# 0    1      not_feature_selection_order    0.5919     0.5816  0.5919
# 1    2      not_feature_selection_order    0.5436     0.5351  0.5436
# 2    3      not_feature_selection_order    0.5561     0.5313  0.5561
# 3    4      not_feature_selection_order    0.5421     0.5210  0.5421
# 4    5  not_feature_selection_not_order    0.5483     0.5480  0.5483
# 5    6  not_feature_selection_not_order    0.5849     0.5832  0.5849
# 6    7  not_feature_selection_not_order    0.5748     0.5727  0.5748
# 7    8  not_feature_selection_not_order    0.5265     0.5428  0.5265
# 8    9          feature_selection_order    0.5296     0.5193  0.5296
# 9   10          feature_selection_order    0.5701     0.5611  0.5701
# 10  11          feature_selection_order    0.5662     0.5592  0.5662
# 11  12          feature_selection_order    0.5265     0.5030  0.5265
# 12  13      feature_selection_not_order    0.5732     0.5589  0.5732
# ...

# %%
calisma_hisse = hisse[hisse["frame_size"]>50]

# %%
hisse.columns
# Out:
# Index(['No', 'CNN Type', 'accuracy', 'precision', 'recall', 'f1-score',
#        'Time Frame Size', 'Execution Time(sec)', 'CNN_Model_id', 'Order id',
#        'Novel Feature', 'Feature selection'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(19,16)})
sns.barplot(x = "Accuracy", y = "Execution Time(sec)", hue="No" ,data = hisse, palette="dark").set_title('');
plt.show()

# %%
sns.catplot(x="CNN_Model_id", y="Accuracy", data=hisse)

# %%
hisse['Accuracy']*100,hisse['Accuracy']

# %%
sns.set(rc={'figure.figsize':(9,6)})
sns.barplot(x = "Time Frame Size", y = "Accuracy", data = hisse);

# %%
sns.set_palette("pastel")
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "frame_size", y = "accuracy", hue = "Novel_Feature", data = hisse);

# %%
sns.set_palette("pastel")
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "frame_size", y = "accuracy", hue = "Novel_Feature", data = hisse);

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "CNN_Model_id", y = "Execution Time(sec)", hue = "Time Frame Size", data = hisse );

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "Preprocessing_Model_id", y = "Execution Time(sec)", hue = "Time Frame Size", data = hisse );

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "Preprocessing_Model_id", y = "Execution Time(sec)", hue = "Feature selection", data = hisse );

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x = "CNN_Model_id", y = "Execution Time(sec)", hue = "Order id", data = hisse );

# %%
#seaborn.set_palette(palette, n_colors=None, desat=None, color_codes=False)
#palette = ["#F72585", "#7209B7", "#3A0CA3", "#4361EE", "#4CC9F0"]
#palette = {50: "#F72585", 75:  "#4CC9F0", 100: "#7209B7", 125: "#3A0CA3"}
sns.catplot(x = "frame_size", y = hisse.accuracy, data= hisse, palette=palette);

# %%
#seaborn.set_palette(palette, n_colors=None, desat=None, color_codes=False)
#palette = ["#F72585", "#7209B7", "#3A0CA3", "#4361EE", "#4CC9F0"]
#palette = {50: "#F72585", 75:  "#4CC9F0", 100: "#7209B7", 125: "#3A0CA3"}
sns.catplot(x = "No", y = hisse.accuracy, data= hisse);

# %%
sns.set(rc={'figure.figsize':(18,12)})
sns.catplot(x="No", y="accuracy", data=hisse, height=8.27, aspect=11.7/8.27)

# %%
# Show each observation with a scatterplot
sns.set(rc={'figure.figsize':(12,8)})
sns.stripplot(
    data=hisse, x="frame_size", y="accuracy" , hue="CNN_Type_id"
    ,  palette="dark"    
)

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.relplot(data=hisse, x="CNN_Model_id", y="Accuracy" ,hue="Time Frame Size"  , 
            palette="dark"  ,style="Order id", size="Accuracy", sizes=(15, 150) )

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.relplot(data=hisse, x="CNN_Model_id", y="Accuracy" ,hue="Time Frame Size"  , 
            palette="dark"  ,style="Novel Feature", size="Accuracy", sizes=(15, 150) )

# %%
sns.set(rc={'figure.figsize':(18,12)})
sns.relplot(data=hisse, x="CNN_Model_id", y="Accuracy" ,hue="Time Frame Size"  , 
            palette="dark"  ,style="Feature selection", size="Accuracy", sizes=(15, 150) )
sns.set(rc={'figure.figsize':(18,12)})

# %%
hisse.columns
# Out:
# Index(['No', 'CNN Type', 'Accuracy', 'precision', 'recall', 'f1-score',
#        'Time Frame Size', 'Execution Time(sec)', 'CNN_Model_id', 'Order id',
#        'Novel Feature', 'Feature selection'],
#       dtype='object')

# %%
flights = hisse.pivot("Time Frame Size", "CNN_Model_id", "Accuracy")
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(flights, annot=True, linewidths=.75, ax=ax  ,annot_kws={'size': 15},
             cbar_kws={'label': 'Accuracy'})

# %%
flights_2 = hisse.pivot("Time Frame Size", "CNN_Model_id", "Execution Time(sec)")
#flights_2 = flights_2.sort_values("Execution Time(sec)", ascending=False)
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(flights_2, annot=True, linewidths=.75, ax=ax,  annot_kws={'size': 12},
             cbar_kws={'label': 'Execution Time(sec)'} )
